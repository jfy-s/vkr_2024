# %%
import csv
import random
import pandas as pd
import heapq

def weighted_duration(min_val=15, max_val=600, scale=100):
    duration = int(random.expovariate(1 / scale))
    if duration < min_val:
        return min_val
    elif duration > max_val:
        return max_val
    else:
        return duration

def generate_data(num_entries):
    time = 0
    data = []
    for _ in range(num_entries):
        time += random.randint(1, 30)
        source = random.randint(0, 9)
        receiver = random.randint(10, 19)
        bandwidth = random.randint(1, 100)
        duration = weighted_duration() 
        data.append([time, source, receiver, bandwidth, duration])
    return data

num_entries = 1500

data_entries = generate_data(num_entries)

with open('data.csv', 'w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['time', 'source', 'receiver', 'bandwidth', 'duration'])
    writer.writerows(data_entries)

print(f'Data written to data.csv with {num_entries} entries.')
# Out:
# Data written to data.csv with 1500 entries.

# %%
G = nx.DiGraph()

G.add_nodes_from(range(30))
flag = 0
while flag == 0:
    a, b = random.sample(list(G.nodes), 2)
    if not G.has_edge(a, b):
        G.add_edge(a, b, bandwidth=random.randint(600, 1500), used_bandwidth=0)
    flag = 1
    for i in range(10):
        for j in range(10, 20):
            flag *= int(nx.has_path(G, i, j))
for (u, v, wt) in G.edges.data('weight'):
    print(f"Edge ({u}, {v}) with weight {wt}")
print(f"Total edges: {len(G.edges)}")
# Out:
# Edge (0, 4) with weight None
# Edge (0, 8) with weight None
# Edge (0, 11) with weight None
# Edge (0, 2) with weight None
# Edge (0, 12) with weight None
# Edge (0, 14) with weight None
# Edge (0, 15) with weight None
# Edge (1, 24) with weight None
# Edge (1, 21) with weight None
# Edge (1, 19) with weight None
# Edge (2, 25) with weight None
# Edge (2, 22) with weight None
# Edge (2, 6) with weight None
# Edge (3, 26) with weight None
# Edge (3, 10) with weight None
# Edge (3, 7) with weight None
# Edge (4, 16) with weight None
# Edge (4, 22) with weight None
# Edge (4, 27) with weight None
# Edge (4, 1) with weight None
# Edge (5, 16) with weight None
# Edge (5, 24) with weight None
# Edge (5, 6) with weight None
# Edge (5, 9) with weight None
# Edge (5, 14) with weight None
# Edge (6, 29) with weight None
# Edge (6, 5) with weight None
# Edge (6, 14) with weight None
# Edge (7, 8) with weight None
# Edge (7, 12) with weight None
# Edge (7, 23) with weight None
# Edge (7, 25) with weight None
# Edge (7, 17) with weight None
# Edge (8, 24) with weight None
# Edge (8, 11) with weight None
# Edge (8, 9) with weight None
# Edge (8, 0) with weight None
# Edge (8, 14) with weight None
# Edge (8, 29) with weight None
# Edge (8, 27) with weight None
# Edge (9, 16) with weight None
# Edge (9, 3) with weight None
# Edge (9, 22) with weight None
# Edge (9, 23) with weight None
# Edge (9, 28) with weight None
# Edge (9, 6) with weight None
# Edge (10, 13) with weight None
# Edge (10, 18) with weight None
# Edge (10, 22) with weight None
# Edge (11, 25) with weight None
# Edge (11, 24) with weight None
# Edge (11, 9) with weight None
# Edge (11, 0) with weight None
# Edge (12, 4) with weight None
# Edge (12, 26) with weight None
# Edge (12, 0) with weight None
# Edge (12, 13) with weight None
# Edge (12, 16) with weight None
# Edge (13, 2) with weight None
# Edge (14, 23) with weight None
# Edge (14, 17) with weight None
# Edge (14, 29) with weight None
# Edge (14, 20) with weight None
# Edge (15, 17) with weight None
# Edge (15, 6) with weight None
# Edge (15, 4) with weight None
# Edge (15, 3) with weight None
# Edge (16, 7) with weight None
# Edge (16, 4) with weight None
# Edge (16, 23) with weight None
# Edge (16, 5) with weight None
# Edge (16, 18) with weight None
# Edge (17, 14) with weight None
# Edge (17, 25) with weight None
# Edge (17, 10) with weight None
# Edge (17, 21) with weight None
# Edge (18, 0) with weight None
# Edge (18, 14) with weight None
# Edge (18, 22) with weight None
# Edge (19, 21) with weight None
# Edge (19, 3) with weight None
# Edge (20, 16) with weight None
# Edge (20, 4) with weight None
# Edge (20, 9) with weight None
# Edge (20, 15) with weight None
# Edge (20, 25) with weight None
# Edge (20, 26) with weight None
# Edge (20, 13) with weight None
# Edge (21, 17) with weight None
# Edge (21, 28) with weight None
# Edge (21, 27) with weight None
# Edge (21, 5) with weight None
# Edge (22, 5) with weight None
# Edge (23, 2) with weight None
# Edge (23, 8) with weight None
# Edge (23, 18) with weight None
# Edge (23, 22) with weight None
# Edge (23, 25) with weight None
# Edge (24, 4) with weight None
# Edge (24, 23) with weight None
# Edge (24, 18) with weight None
# Edge (24, 2) with weight None
# Edge (24, 13) with weight None
# Edge (24, 16) with weight None
# Edge (24, 14) with weight None
# Edge (25, 11) with weight None
# Edge (25, 15) with weight None
# Edge (25, 27) with weight None
# Edge (25, 22) with weight None
# Edge (25, 17) with weight None
# Edge (25, 0) with weight None
# Edge (25, 4) with weight None
# Edge (26, 27) with weight None
# Edge (26, 20) with weight None
# Edge (26, 29) with weight None
# Edge (26, 23) with weight None
# Edge (26, 28) with weight None
# Edge (26, 18) with weight None
# Edge (27, 13) with weight None
# Edge (27, 29) with weight None
# Edge (27, 18) with weight None
# Edge (27, 9) with weight None
# Edge (27, 20) with weight None
# Edge (28, 9) with weight None
# Edge (29, 16) with weight None
# Edge (29, 25) with weight None
# Edge (29, 5) with weight None
# Edge (29, 13) with weight None
# Edge (29, 21) with weight None
# Edge (29, 20) with weight None
# Total edges: 130

# %%
data = pd.read_csv('data.csv')

def update_graph(time, active_requests):
    for u, v in G.edges:
        G[u][v]['used_bandwidth'] = 0
    for req in active_requests.values():
        if time < req['end_time']:
            path = req['path']
            for i in range(len(path) - 1):
                u, v = path[i], path[i+1]
                G[u][v]['used_bandwidth'] += req['bandwidth']
    for u, v in G.edges():
        available_bw = G[u][v]['bandwidth'] - G[u][v]['used_bandwidth']
        G[u][v]['weight'] = float('inf') if available_bw <= 0 else 1 / available_bw

def find_path(source, receiver, bandwidth):
    original_weights = {}
    for u, v in G.edges():
        original_weights[(u, v)] = G[u][v]['weight']
        available_bw = G[u][v]['bandwidth'] - G[u][v]['used_bandwidth']
        G[u][v]['weight'] = float('inf') if available_bw < bandwidth else 1 / available_bw
    try:
        path = nx.shortest_path(G, source=source, target=receiver, weight='weight')
        print(f"Found path from {source} to {receiver} with required bandwidth {bandwidth}: {path}")
    except nx.NetworkXNoPath:
        path = None
        print(f"No path available from {source} to {receiver} with required bandwidth {bandwidth}")
    for (u, v), weight in original_weights.items():
        G[u][v]['weight'] = weight

    return path
active_requests = {}

max_time = data['time'].max() + data['duration'].max()
for current_time in range(1, max_time + 1):
    print(f"Processing time {current_time}")
    new_requests = data[data['time'] == current_time]
    for _, row in new_requests.iterrows():
        if row.name not in active_requests:
            path = find_path(row['source'], row['receiver'], row['bandwidth'])
            if path:
                active_requests[row.name] = {
                    'source': row['source'],
                    'receiver': row['receiver'],
                    'bandwidth': row['bandwidth'],
                    'end_time': row['time'] + row['duration'],
                    'path': path
                }
    active_requests = {k: v for k, v in active_requests.items() if v['end_time'] >= current_time}
    update_graph(current_time, active_requests)
    print(f"Active requests at time {current_time}: {list(active_requests.keys())}")
# Out:
# Processing time 1
# Active requests at time 1: []
# Processing time 2
# Active requests at time 2: []
# Processing time 3
# Active requests at time 3: []
# Processing time 4
# Active requests at time 4: []
# Processing time 5
# Active requests at time 5: []
# Processing time 6
# Found path from 4 to 19 with required bandwidth 64: [4, 1, 19]
# Active requests at time 6: [0]
# Processing time 7
# Active requests at time 7: [0]
# Processing time 8
# Active requests at time 8: [0]
# Processing time 9
# Active requests at time 9: [0]
# Processing time 10
# Active requests at time 10: [0]
# Processing time 11
# Active requests at time 11: [0]
# Processing time 12
# Active requests at time 12: [0]
# Processing time 13
# Found path from 6 to 13 with required bandwidth 68: [6, 29, 13]
# Active requests at time 13: [0, 1]
# Processing time 14
# Found path from 6 to 15 with required bandwidth 26: [6, 14, 20, 15]
# Active requests at time 14: [0, 1, 2]
# Processing time 15
# Active requests at time 15: [0, 1, 2]
# Processing time 16
# Active requests at time 16: [0, 1, 2]
# Processing time 17
# Active requests at time 17: [0, 1, 2]
# Processing time 18
# Active requests at time 18: [0, 1, 2]
# Processing time 19
# Active requests at time 19: [0, 1, 2]
# Processing time 20
# Active requests at time 20: [0, 1, 2]
# Processing time 21
# Active requests at time 21: [0, 1, 2]
# Processing time 22
# Active requests at time 22: [0, 1, 2]
# Processing time 23
# Found path from 1 to 18 with required bandwidth 3: [1, 24, 18]
# Active requests at time 23: [0, 1, 2, 3]
# Processing time 24
# Active requests at time 24: [0, 1, 2, 3]
# Processing time 25
# Active requests at time 25: [0, 1, 2, 3]
# Processing time 26
# Active requests at time 26: [0, 1, 2, 3]
# Processing time 27
# Found path from 5 to 10 with required bandwidth 50: [5, 9, 3, 10]
# Active requests at time 27: [0, 1, 2, 3, 4]
# Processing time 28
# Active requests at time 28: [0, 1, 2, 3, 4]
# Processing time 29
# Active requests at time 29: [0, 1, 2, 3, 4]
# Processing time 30
# Active requests at time 30: [0, 1, 2, 3, 4]
# Processing time 31
# Active requests at time 31: [0, 1, 2, 3, 4]
# Processing time 32
# Active requests at time 32: [0, 1, 2, 3, 4]
# Processing time 33
# Found path from 9 to 11 with required bandwidth 43: [9, 23, 8, 11]
# Active requests at time 33: [0, 1, 2, 3, 4, 5]
# Processing time 34
# Active requests at time 34: [0, 1, 2, 3, 4, 5]
# Processing time 35
# Active requests at time 35: [0, 1, 2, 3, 4, 5]
# Processing time 36
# Active requests at time 36: [0, 1, 2, 3, 4, 5]
# Processing time 37
# Active requests at time 37: [0, 1, 2, 3, 4, 5]
# Processing time 38
# Active requests at time 38: [0, 1, 2, 3, 4, 5]
# Processing time 39
# Active requests at time 39: [0, 1, 2, 4, 5]
# Processing time 40
# Active requests at time 40: [0, 1, 2, 4, 5]
# Processing time 41
# Active requests at time 41: [0, 1, 2, 4, 5]
# Processing time 42
# Active requests at time 42: [0, 1, 2, 4, 5]
# Processing time 43
# Active requests at time 43: [0, 1, 2, 4, 5]
# Processing time 44
# Active requests at time 44: [0, 1, 2, 4, 5]
# Processing time 45
# Active requests at time 45: [0, 1, 2, 4, 5]
# Processing time 46
# Active requests at time 46: [0, 1, 2, 4, 5]
# Processing time 47
# Active requests at time 47: [0, 1, 2, 4, 5]
# Processing time 48
# Active requests at time 48: [0, 1, 2, 4, 5]
# Processing time 49
# Active requests at time 49: [0, 1, 2, 4, 5]
# Processing time 50
# Active requests at time 50: [0, 1, 2, 4, 5]
# Processing time 51
# Found path from 2 to 14 with required bandwidth 14: [2, 6, 14]
# Active requests at time 51: [0, 1, 2, 4, 5, 6]
# Processing time 52
# Active requests at time 52: [0, 1, 2, 4, 5, 6]
# Processing time 53
# Active requests at time 53: [0, 1, 2, 4, 5, 6]
# Processing time 54
# Active requests at time 54: [0, 1, 2, 4, 5, 6]
# Processing time 55
# Active requests at time 55: [0, 1, 2, 4, 5, 6]
# Processing time 56
# Active requests at time 56: [0, 1, 2, 4, 5, 6]
# Processing time 57
# Active requests at time 57: [0, 1, 2, 4, 5, 6]
# Processing time 58
# Active requests at time 58: [1, 2, 4, 5, 6]
# Processing time 59
# Active requests at time 59: [1, 2, 4, 5, 6]
# Processing time 60
# Active requests at time 60: [1, 2, 4, 5, 6]
# Processing time 61
# Active requests at time 61: [1, 2, 5, 6]
# Processing time 62
# Active requests at time 62: [1, 2, 5, 6]
# Processing time 63
# Active requests at time 63: [1, 2, 5, 6]
# Processing time 64
# Active requests at time 64: [1, 2, 5, 6]
# Processing time 65
# Found path from 6 to 17 with required bandwidth 47: [6, 14, 17]
# Active requests at time 65: [1, 2, 5, 6, 7]
# Processing time 66
# Active requests at time 66: [1, 2, 5, 6, 7]
# Processing time 67
# Active requests at time 67: [1, 2, 5, 6, 7]
# Processing time 68
# Active requests at time 68: [1, 2, 5, 6, 7]
# Processing time 69
# Active requests at time 69: [1, 2, 5, 6, 7]
# Processing time 70
# Active requests at time 70: [1, 2, 5, 6, 7]
# Processing time 71
# Active requests at time 71: [1, 2, 5, 6, 7]
# Processing time 72
# Active requests at time 72: [1, 2, 5, 6, 7]
# Processing time 73
# Active requests at time 73: [1, 2, 5, 6, 7]
# Processing time 74
# Active requests at time 74: [1, 2, 5, 6, 7]
# Processing time 75
# Active requests at time 75: [1, 2, 5, 6, 7]
# Processing time 76
# Active requests at time 76: [1, 2, 5, 6, 7]
# Processing time 77
# Active requests at time 77: [1, 2, 5, 6, 7]
# Processing time 78
# Active requests at time 78: [1, 2, 5, 6, 7]
# Processing time 79
# Active requests at time 79: [1, 2, 5, 6, 7]
# Processing time 80
# Active requests at time 80: [1, 2, 5, 6, 7]
# Processing time 81
# Active requests at time 81: [1, 2, 5]
# Processing time 82
# Active requests at time 82: [1, 2, 5]
# Processing time 83
# Found path from 9 to 18 with required bandwidth 69: [9, 16, 18]
# Active requests at time 83: [1, 2, 5, 8]
# Processing time 84
# Active requests at time 84: [1, 2, 5, 8]
# Processing time 85
# Active requests at time 85: [1, 2, 5, 8]
# Processing time 86
# Active requests at time 86: [1, 2, 5, 8]
# Processing time 87
# Active requests at time 87: [1, 2, 5, 8]
# Processing time 88
# Active requests at time 88: [1, 2, 5, 8]
# Processing time 89
# Active requests at time 89: [1, 2, 5, 8]
# Processing time 90
# Active requests at time 90: [1, 2, 5, 8]
# Processing time 91
# Active requests at time 91: [1, 2, 5, 8]
# Processing time 92
# Active requests at time 92: [1, 2, 5, 8]
# Processing time 93
# Active requests at time 93: [1, 2, 5, 8]
# Processing time 94
# Active requests at time 94: [1, 2, 5, 8]
# Processing time 95
# Active requests at time 95: [1, 2, 5, 8]
# Processing time 96
# Active requests at time 96: [1, 2, 5, 8]
# Processing time 97
# Active requests at time 97: [1, 2, 5, 8]
# Processing time 98
# Active requests at time 98: [1, 2, 5, 8]
# Processing time 99
# Active requests at time 99: [1, 2, 5, 8]
# Processing time 100
# Active requests at time 100: [1, 2, 5, 8]
# Processing time 101
# Active requests at time 101: [1, 2, 5, 8]
# Processing time 102
# Found path from 8 to 15 with required bandwidth 33: [8, 0, 15]
# Active requests at time 102: [1, 2, 5, 8, 9]
# Processing time 103
# Active requests at time 103: [1, 2, 5, 8, 9]
# Processing time 104
# Active requests at time 104: [1, 2, 5, 8, 9]
# Processing time 105
# Active requests at time 105: [1, 2, 5, 8, 9]
# Processing time 106
# Active requests at time 106: [1, 2, 5, 8, 9]
# Processing time 107
# Active requests at time 107: [1, 2, 5, 8, 9]
# Processing time 108
# Active requests at time 108: [1, 2, 5, 8, 9]
# Processing time 109
# Active requests at time 109: [1, 2, 5, 8, 9]
# Processing time 110
# Active requests at time 110: [1, 2, 5, 8, 9]
# Processing time 111
# Active requests at time 111: [1, 2, 5, 8, 9]
# Processing time 112
# Active requests at time 112: [1, 2, 5, 8, 9]
# Processing time 113
# Active requests at time 113: [1, 2, 5, 8, 9]
# Processing time 114
# Active requests at time 114: [1, 2, 5, 8, 9]
# Processing time 115
# Active requests at time 115: [1, 2, 5, 8, 9]
# Processing time 116
# Active requests at time 116: [1, 2, 5, 8, 9]
# Processing time 117
# Active requests at time 117: [1, 2, 5, 8, 9]
# Processing time 118
# Active requests at time 118: [1, 2, 5, 8]
# Processing time 119
# Active requests at time 119: [1, 2, 5, 8]
# Processing time 120
# Active requests at time 120: [1, 2, 5, 8]
# Processing time 121
# Found path from 9 to 13 with required bandwidth 5: [9, 6, 29, 13]
# Active requests at time 121: [1, 2, 5, 8, 10]
# Processing time 122
# Active requests at time 122: [1, 2, 5, 8, 10]
# Processing time 123
# Active requests at time 123: [1, 2, 5, 8, 10]
# Processing time 124
# Active requests at time 124: [1, 2, 5, 8, 10]
# Processing time 125
# Active requests at time 125: [1, 2, 5, 8, 10]
# Processing time 126
# Active requests at time 126: [1, 2, 5, 8, 10]
# Processing time 127
# Active requests at time 127: [1, 2, 5, 8, 10]
# Processing time 128
# Active requests at time 128: [1, 2, 5, 8, 10]
# Processing time 129
# Active requests at time 129: [1, 2, 5, 8, 10]
# Processing time 130
# Active requests at time 130: [1, 2, 5, 8, 10]
# Processing time 131
# Active requests at time 131: [1, 2, 5, 8, 10]
# Processing time 132
# Active requests at time 132: [1, 2, 5, 8, 10]
# Processing time 133
# Found path from 5 to 19 with required bandwidth 35: [5, 24, 4, 1, 19]
# Active requests at time 133: [1, 2, 5, 8, 10, 11]
# Processing time 134
# Active requests at time 134: [1, 2, 5, 8, 10, 11]
# Processing time 135
# Active requests at time 135: [1, 2, 5, 8, 10, 11]
# Processing time 136
# Active requests at time 136: [1, 2, 5, 8, 10, 11]
# Processing time 137
# Active requests at time 137: [1, 2, 5, 8, 11]
# Processing time 138
# Active requests at time 138: [1, 2, 5, 8, 11]
# Processing time 139
# Active requests at time 139: [1, 2, 5, 8, 11]
# Processing time 140
# Active requests at time 140: [1, 2, 5, 8, 11]
# Processing time 141
# Active requests at time 141: [1, 2, 5, 8, 11]
# Processing time 142
# Active requests at time 142: [1, 2, 5, 8, 11]
# Processing time 143
# Active requests at time 143: [1, 2, 5, 8, 11]
# Processing time 144
# Active requests at time 144: [1, 2, 5, 8, 11]
# Processing time 145
# Active requests at time 145: [1, 2, 5, 8, 11]
# Processing time 146
# Active requests at time 146: [1, 2, 5, 8, 11]
# Processing time 147
# Found path from 4 to 14 with required bandwidth 87: [4, 22, 5, 14]
# Active requests at time 147: [1, 2, 5, 8, 11, 12]
# Processing time 148
# Active requests at time 148: [1, 2, 5, 8, 11, 12]
# Processing time 149
# Active requests at time 149: [1, 2, 5, 8, 11, 12]
# Processing time 150
# Found path from 1 to 11 with required bandwidth 1: [1, 21, 17, 25, 11]
# Active requests at time 150: [1, 2, 5, 8, 11, 12, 13]
# Processing time 151
# Active requests at time 151: [1, 2, 5, 8, 11, 12, 13]
# Processing time 152
# Active requests at time 152: [1, 2, 5, 8, 11, 12, 13]
# Processing time 153
# Active requests at time 153: [1, 2, 5, 8, 11, 12, 13]
# Processing time 154
# Active requests at time 154: [1, 2, 5, 8, 11, 12, 13]
# Processing time 155
# Active requests at time 155: [1, 2, 5, 8, 11, 12, 13]
# Processing time 156
# Active requests at time 156: [1, 2, 5, 8, 11, 12, 13]
# Processing time 157
# Active requests at time 157: [1, 2, 5, 8, 11, 12, 13]
# Processing time 158
# Active requests at time 158: [1, 2, 5, 8, 11, 12, 13]
# Processing time 159
# Active requests at time 159: [1, 2, 5, 8, 11, 12, 13]
# Processing time 160
# Active requests at time 160: [1, 2, 5, 8, 11, 12, 13]
# Processing time 161
# Found path from 8 to 18 with required bandwidth 87: [8, 24, 18]
# Active requests at time 161: [1, 2, 5, 8, 11, 12, 13, 14]
# Processing time 162
# Active requests at time 162: [1, 2, 5, 8, 11, 12, 13, 14]
# Processing time 163
# Active requests at time 163: [1, 2, 5, 8, 11, 12, 13, 14]
# Processing time 164
# Active requests at time 164: [1, 2, 5, 8, 11, 12, 13, 14]
# Processing time 165
# Active requests at time 165: [1, 2, 5, 8, 11, 12, 13, 14]
# Processing time 166
# Active requests at time 166: [1, 2, 5, 8, 11, 12, 13, 14]
# Processing time 167
# Active requests at time 167: [1, 2, 5, 8, 11, 12, 13, 14]
# Processing time 168
# Active requests at time 168: [1, 2, 5, 8, 11, 12, 13, 14]
# Processing time 169
# Active requests at time 169: [2, 5, 8, 11, 12, 13, 14]
# Processing time 170
# Active requests at time 170: [2, 5, 8, 11, 12, 13, 14]
# Processing time 171
# Active requests at time 171: [2, 5, 8, 11, 12, 13, 14]
# Processing time 172
# Active requests at time 172: [2, 5, 8, 11, 12, 13, 14]
# Processing time 173
# Active requests at time 173: [2, 5, 8, 11, 12, 13, 14]
# Processing time 174
# Active requests at time 174: [2, 5, 8, 11, 12, 13, 14]
# Processing time 175
# Active requests at time 175: [2, 5, 8, 11, 12, 13, 14]
# Processing time 176
# Active requests at time 176: [2, 5, 8, 11, 12, 13, 14]
# Processing time 177
# Active requests at time 177: [2, 5, 8, 11, 12, 14]
# Processing time 178
# Active requests at time 178: [2, 5, 8, 11, 12, 14]
# Processing time 179
# Active requests at time 179: [2, 8, 11, 12, 14]
# Processing time 180
# Active requests at time 180: [2, 8, 11, 12, 14]
# Processing time 181
# Active requests at time 181: [2, 8, 11, 12, 14]
# Processing time 182
# Active requests at time 182: [2, 8, 11, 12, 14]
# Processing time 183
# Active requests at time 183: [2, 8, 11, 12, 14]
# Processing time 184
# Found path from 9 to 16 with required bandwidth 92: [9, 16]
# Active requests at time 184: [2, 8, 11, 12, 14, 15]
# Processing time 185
# Active requests at time 185: [2, 8, 11, 12, 14, 15]
# Processing time 186
# Active requests at time 186: [2, 8, 11, 12, 14, 15]
# Processing time 187
# Active requests at time 187: [2, 8, 11, 12, 14, 15]
# Processing time 188
# Active requests at time 188: [2, 8, 11, 12, 14, 15]
# Processing time 189
# Active requests at time 189: [2, 8, 11, 12, 14, 15]
# Processing time 190
# Active requests at time 190: [2, 8, 11, 12, 14, 15]
# Processing time 191
# Active requests at time 191: [2, 8, 11, 12, 14, 15]
# Processing time 192
# Active requests at time 192: [2, 8, 11, 12, 14, 15]
# Processing time 193
# Active requests at time 193: [2, 8, 11, 12, 14, 15]
# Processing time 194
# Active requests at time 194: [2, 8, 11, 12, 14, 15]
# Processing time 195
# Active requests at time 195: [2, 8, 11, 12, 14, 15]
# Processing time 196
# Active requests at time 196: [2, 8, 11, 12, 14, 15]
# Processing time 197
# Active requests at time 197: [2, 8, 11, 12, 14, 15]
# Processing time 198
# Active requests at time 198: [2, 8, 11, 12, 14, 15]
# Processing time 199
# Active requests at time 199: [2, 8, 11, 12, 14, 15]
# Processing time 200
# Active requests at time 200: [2, 8, 11, 12, 14, 15]
# Processing time 201
# Active requests at time 201: [2, 8, 11, 12, 14, 15]
# Processing time 202
# Active requests at time 202: [2, 8, 11, 12, 14, 15]
# Processing time 203
# Active requests at time 203: [2, 8, 11, 12, 14, 15]
# Processing time 204
# Active requests at time 204: [2, 8, 11, 12, 14, 15]
# Processing time 205
# Active requests at time 205: [2, 8, 11, 12, 14, 15]
# Processing time 206
# Active requests at time 206: [2, 8, 11, 12, 14, 15]
# Processing time 207
# Active requests at time 207: [2, 8, 11, 12, 14, 15]
# Processing time 208
# Active requests at time 208: [2, 8, 11, 12, 14, 15]
# Processing time 209
# Active requests at time 209: [2, 8, 11, 12, 14, 15]
# Processing time 210
# Active requests at time 210: [2, 8, 11, 12, 14, 15]
# Processing time 211
# Found path from 5 to 17 with required bandwidth 42: [5, 14, 17]
# Active requests at time 211: [2, 11, 12, 14, 15, 16]
# Processing time 212
# Active requests at time 212: [2, 11, 12, 14, 15, 16]
# Processing time 213
# Active requests at time 213: [2, 11, 12, 14, 15, 16]
# Processing time 214
# Active requests at time 214: [2, 12, 14, 15, 16]
# Processing time 215
# Active requests at time 215: [2, 12, 14, 15, 16]
# Processing time 216
# Active requests at time 216: [2, 12, 14, 15, 16]
# Processing time 217
# Active requests at time 217: [2, 12, 14, 15, 16]
# Processing time 218
# Active requests at time 218: [2, 12, 14, 15, 16]
# Processing time 219
# Active requests at time 219: [2, 12, 14, 15, 16]
# Processing time 220
# Active requests at time 220: [2, 12, 14, 15, 16]
# Processing time 221
# Active requests at time 221: [2, 12, 14, 15, 16]
# Processing time 222
# Active requests at time 222: [2, 12, 14, 15, 16]
# Processing time 223
# Active requests at time 223: [2, 12, 14, 15, 16]
# Processing time 224
# Active requests at time 224: [2, 12, 14, 15, 16]
# Processing time 225
# Active requests at time 225: [2, 12, 14, 15, 16]
# Processing time 226
# Active requests at time 226: [2, 12, 14, 15, 16]
# Processing time 227
# Active requests at time 227: [2, 12, 15, 16]
# Processing time 228
# Active requests at time 228: [2, 12, 15, 16]
# Processing time 229
# Active requests at time 229: [2, 12, 15, 16]
# Processing time 230
# Active requests at time 230: [2, 12, 15, 16]
# Processing time 231
# Active requests at time 231: [2, 12, 15, 16]
# Processing time 232
# Active requests at time 232: [2, 12, 15, 16]
# Processing time 233
# Found path from 8 to 19 with required bandwidth 84: [8, 24, 4, 1, 19]
# Active requests at time 233: [2, 12, 15, 16, 17]
# Processing time 234
# Active requests at time 234: [2, 12, 15, 16, 17]
# Processing time 235
# Active requests at time 235: [2, 12, 15, 16, 17]
# Processing time 236
# Active requests at time 236: [2, 12, 15, 16, 17]
# Processing time 237
# Active requests at time 237: [2, 12, 15, 16, 17]
# Processing time 238
# Active requests at time 238: [2, 12, 15, 16, 17]
# Processing time 239
# Active requests at time 239: [2, 12, 15, 16, 17]
# Processing time 240
# Found path from 1 to 11 with required bandwidth 4: [1, 21, 17, 25, 11]
# Active requests at time 240: [2, 12, 15, 16, 17, 18]
# Processing time 241
# Active requests at time 241: [2, 12, 15, 16, 17, 18]
# Processing time 242
# Active requests at time 242: [2, 12, 15, 16, 17, 18]
# Processing time 243
# Active requests at time 243: [2, 12, 15, 16, 17, 18]
# Processing time 244
# Active requests at time 244: [2, 12, 15, 16, 17, 18]
# Processing time 245
# Active requests at time 245: [2, 16, 17, 18]
# Processing time 246
# Active requests at time 246: [2, 16, 17, 18]
# Processing time 247
# Active requests at time 247: [2, 16, 17, 18]
# Processing time 248
# Active requests at time 248: [2, 16, 17, 18]
# Processing time 249
# Active requests at time 249: [2, 16, 17, 18]
# Processing time 250
# Active requests at time 250: [2, 16, 17, 18]
# Processing time 251
# Active requests at time 251: [2, 16, 17, 18]
# Processing time 252
# Found path from 6 to 16 with required bandwidth 45: [6, 5, 16]
# Active requests at time 252: [2, 17, 18, 19]
# Processing time 253
# Active requests at time 253: [2, 17, 18, 19]
# Processing time 254
# Active requests at time 254: [2, 17, 18, 19]
# Processing time 255
# Active requests at time 255: [2, 17, 18, 19]
# Processing time 256
# Active requests at time 256: [2, 17, 18, 19]
# Processing time 257
# Active requests at time 257: [2, 17, 18, 19]
# Processing time 258
# Active requests at time 258: [2, 17, 18, 19]
# Processing time 259
# Active requests at time 259: [2, 17, 18, 19]
# Processing time 260
# Active requests at time 260: [2, 17, 18, 19]
# Processing time 261
# Active requests at time 261: [2, 17, 18, 19]
# Processing time 262
# Active requests at time 262: [2, 17, 18, 19]
# Processing time 263
# Active requests at time 263: [2, 17, 18, 19]
# Processing time 264
# Active requests at time 264: [2, 17, 18, 19]
# Processing time 265
# Active requests at time 265: [2, 17, 18, 19]
# Processing time 266
# Active requests at time 266: [2, 17, 18, 19]
# Processing time 267
# Found path from 9 to 18 with required bandwidth 77: [9, 16, 18]
# Active requests at time 267: [2, 17, 18, 19, 20]
# Processing time 268
# Active requests at time 268: [2, 17, 18, 19, 20]
# Processing time 269
# Active requests at time 269: [2, 17, 18, 19, 20]
# Processing time 270
# Active requests at time 270: [2, 17, 18, 19, 20]
# Processing time 271
# Active requests at time 271: [2, 17, 18, 19, 20]
# Processing time 272
# Active requests at time 272: [2, 17, 18, 19, 20]
# Processing time 273
# Active requests at time 273: [2, 17, 18, 19, 20]
# Processing time 274
# Active requests at time 274: [2, 17, 18, 19, 20]
# Processing time 275
# Found path from 6 to 10 with required bandwidth 4: [6, 14, 17, 10]
# Active requests at time 275: [2, 17, 18, 19, 20, 21]
# Processing time 276
# Active requests at time 276: [2, 17, 18, 19, 20, 21]
# Processing time 277
# Active requests at time 277: [2, 17, 18, 19, 20, 21]
# Processing time 278
# Active requests at time 278: [2, 17, 18, 19, 20, 21]
# Processing time 279
# Active requests at time 279: [2, 17, 18, 19, 20, 21]
# Processing time 280
# Active requests at time 280: [2, 17, 18, 19, 20, 21]
# Processing time 281
# Active requests at time 281: [2, 17, 18, 19, 20, 21]
# Processing time 282
# Active requests at time 282: [2, 17, 18, 19, 20, 21]
# Processing time 283
# Active requests at time 283: [2, 17, 18, 19, 20, 21]
# Processing time 284
# Active requests at time 284: [2, 17, 18, 19, 20, 21]
# Processing time 285
# Active requests at time 285: [2, 17, 18, 19, 20, 21]
# Processing time 286
# Active requests at time 286: [2, 17, 18, 19, 20, 21]
# Processing time 287
# Active requests at time 287: [2, 17, 18, 19, 20, 21]
# Processing time 288
# Found path from 1 to 17 with required bandwidth 32: [1, 21, 17]
# Active requests at time 288: [2, 17, 18, 19, 20, 21, 22]
# Processing time 289
# Active requests at time 289: [2, 17, 18, 19, 20, 21, 22]
# Processing time 290
# Active requests at time 290: [2, 17, 18, 19, 20, 21, 22]
# Processing time 291
# Active requests at time 291: [2, 17, 18, 19, 20, 21, 22]
# Processing time 292
# Active requests at time 292: [2, 17, 18, 19, 20, 21, 22]
# Processing time 293
# Active requests at time 293: [2, 17, 18, 19, 20, 21, 22]
# Processing time 294
# Active requests at time 294: [2, 17, 18, 19, 20, 21, 22]
# Processing time 295
# Active requests at time 295: [2, 17, 18, 19, 20, 21, 22]
# Processing time 296
# Active requests at time 296: [2, 17, 18, 19, 20, 21, 22]
# Processing time 297
# Active requests at time 297: [2, 17, 18, 19, 20, 21, 22]
# Processing time 298
# Found path from 0 to 13 with required bandwidth 7: [0, 8, 29, 13]
# Active requests at time 298: [2, 17, 18, 19, 20, 21, 22, 23]
# Processing time 299
# Active requests at time 299: [2, 17, 18, 19, 20, 21, 22, 23]
# Processing time 300
# Active requests at time 300: [2, 17, 18, 19, 20, 21, 22, 23]
# Processing time 301
# Active requests at time 301: [2, 17, 18, 19, 20, 21, 22, 23]
# Processing time 302
# Active requests at time 302: [2, 17, 18, 19, 20, 21, 22, 23]
# Processing time 303
# Active requests at time 303: [2, 17, 18, 19, 20, 21, 22, 23]
# Processing time 304
# Active requests at time 304: [2, 17, 18, 19, 20, 21, 22, 23]
# Processing time 305
# Active requests at time 305: [2, 17, 18, 19, 20, 21, 22, 23]
# Processing time 306
# Active requests at time 306: [2, 17, 18, 19, 20, 21, 22, 23]
# Processing time 307
# Active requests at time 307: [2, 17, 18, 19, 20, 21, 23]
# Processing time 308
# Active requests at time 308: [2, 17, 18, 19, 20, 21, 23]
# Processing time 309
# Active requests at time 309: [2, 17, 18, 19, 20, 21, 23]
# Processing time 310
# Active requests at time 310: [2, 17, 18, 19, 20, 21, 23]
# Processing time 311
# Active requests at time 311: [2, 17, 18, 19, 20, 21, 23]
# Processing time 312
# Active requests at time 312: [2, 17, 18, 19, 20, 21, 23]
# Processing time 313
# Active requests at time 313: [2, 17, 18, 19, 20, 21, 23]
# Processing time 314
# Active requests at time 314: [2, 17, 18, 19, 20, 21, 23]
# Processing time 315
# Active requests at time 315: [2, 17, 18, 19, 20, 21, 23]
# Processing time 316
# Active requests at time 316: [2, 17, 18, 19, 20, 21, 23]
# Processing time 317
# Active requests at time 317: [2, 17, 18, 19, 20, 21, 23]
# Processing time 318
# Active requests at time 318: [2, 17, 18, 19, 20, 21, 23]
# Processing time 319
# Active requests at time 319: [2, 17, 18, 19, 20, 21, 23]
# Processing time 320
# Active requests at time 320: [2, 17, 18, 19, 20, 21, 23]
# Processing time 321
# Found path from 1 to 18 with required bandwidth 86: [1, 24, 18]
# Active requests at time 321: [2, 17, 18, 19, 20, 21, 23, 24]
# Processing time 322
# Active requests at time 322: [2, 17, 18, 19, 20, 21, 23, 24]
# Processing time 323
# Active requests at time 323: [2, 17, 18, 19, 20, 21, 23, 24]
# Processing time 324
# Active requests at time 324: [2, 17, 18, 19, 20, 21, 23, 24]
# Processing time 325
# Active requests at time 325: [2, 17, 18, 19, 20, 21, 23, 24]
# Processing time 326
# Active requests at time 326: [2, 17, 18, 19, 20, 21, 23, 24]
# Processing time 327
# Active requests at time 327: [2, 17, 18, 19, 20, 21, 23, 24]
# Processing time 328
# Active requests at time 328: [2, 17, 18, 19, 20, 21, 23, 24]
# Processing time 329
# Active requests at time 329: [2, 17, 18, 19, 20, 21, 23, 24]
# Processing time 330
# Active requests at time 330: [2, 17, 18, 19, 20, 21, 23, 24]
# Processing time 331
# Active requests at time 331: [2, 17, 18, 19, 20, 21, 23, 24]
# Processing time 332
# Active requests at time 332: [2, 17, 18, 19, 20, 21, 23, 24]
# Processing time 333
# Active requests at time 333: [2, 17, 18, 19, 20, 21, 23, 24]
# Processing time 334
# Active requests at time 334: [2, 17, 18, 19, 20, 21, 23, 24]
# Processing time 335
# Active requests at time 335: [2, 17, 18, 19, 20, 21, 23, 24]
# Processing time 336
# Active requests at time 336: [2, 17, 18, 19, 20, 21, 23, 24]
# Processing time 337
# Active requests at time 337: [2, 17, 18, 19, 21, 23, 24]
# Processing time 338
# Active requests at time 338: [2, 17, 18, 19, 21, 23, 24]
# Processing time 339
# Active requests at time 339: [2, 17, 18, 19, 21, 23, 24]
# Processing time 340
# Active requests at time 340: [2, 17, 18, 19, 21, 23, 24]
# Processing time 341
# Active requests at time 341: [2, 17, 18, 19, 21, 23, 24]
# Processing time 342
# Active requests at time 342: [2, 17, 18, 19, 21, 23, 24]
# Processing time 343
# Active requests at time 343: [2, 17, 18, 19, 21, 23, 24]
# Processing time 344
# Active requests at time 344: [2, 17, 18, 19, 21, 23, 24]
# Processing time 345
# Active requests at time 345: [2, 17, 18, 19, 21, 23, 24]
# Processing time 346
# Active requests at time 346: [2, 17, 18, 19, 21, 23, 24]
# Processing time 347
# Active requests at time 347: [2, 17, 18, 19, 21, 23, 24]
# Processing time 348
# Active requests at time 348: [2, 17, 18, 19, 21, 23, 24]
# Processing time 349
# Active requests at time 349: [2, 17, 18, 19, 21, 23, 24]
# Processing time 350
# Active requests at time 350: [2, 17, 18, 19, 21, 23, 24]
# Processing time 351
# Found path from 4 to 13 with required bandwidth 83: [4, 27, 13]
# Active requests at time 351: [2, 17, 18, 19, 21, 23, 24, 25]
# Processing time 352
# Active requests at time 352: [17, 18, 19, 21, 23, 24, 25]
# Processing time 353
# Active requests at time 353: [17, 18, 19, 21, 23, 24, 25]
# Processing time 354
# Active requests at time 354: [17, 18, 19, 21, 23, 24, 25]
# Processing time 355
# Active requests at time 355: [17, 18, 19, 21, 23, 24, 25]
# Processing time 356
# Active requests at time 356: [17, 18, 19, 21, 23, 24, 25]
# Processing time 357
# Active requests at time 357: [17, 18, 19, 21, 23, 24, 25]
# Processing time 358
# Active requests at time 358: [17, 18, 19, 21, 23, 24, 25]
# Processing time 359
# Active requests at time 359: [17, 18, 19, 21, 23, 24, 25]
# Processing time 360
# Active requests at time 360: [17, 18, 19, 21, 23, 24, 25]
# Processing time 361
# Active requests at time 361: [17, 18, 19, 21, 23, 24, 25]
# Processing time 362
# Found path from 3 to 18 with required bandwidth 75: [3, 10, 18]
# Active requests at time 362: [17, 18, 19, 21, 23, 24, 25, 26]
# Processing time 363
# Active requests at time 363: [17, 18, 19, 21, 23, 24, 25, 26]
# Processing time 364
# Found path from 8 to 14 with required bandwidth 48: [8, 14]
# Active requests at time 364: [17, 18, 19, 21, 23, 24, 25, 26, 27]
# Processing time 365
# Active requests at time 365: [18, 19, 21, 23, 24, 25, 26, 27]
# Processing time 366
# Active requests at time 366: [18, 19, 21, 23, 24, 25, 26, 27]
# Processing time 367
# Active requests at time 367: [18, 19, 21, 23, 24, 25, 26, 27]
# Processing time 368
# Active requests at time 368: [18, 19, 21, 23, 24, 25, 26, 27]
# Processing time 369
# Found path from 0 to 19 with required bandwidth 92: [0, 4, 1, 19]
# Active requests at time 369: [18, 19, 21, 23, 24, 25, 26, 27, 28]
# Processing time 370
# Active requests at time 370: [18, 19, 21, 23, 24, 25, 26, 27, 28]
# Processing time 371
# Active requests at time 371: [18, 19, 21, 23, 24, 25, 26, 27, 28]
# Processing time 372
# Active requests at time 372: [18, 19, 21, 23, 24, 25, 26, 27, 28]
# Processing time 373
# Active requests at time 373: [18, 19, 21, 23, 24, 25, 26, 27, 28]
# Processing time 374
# Active requests at time 374: [18, 19, 21, 23, 24, 25, 26, 27, 28]
# Processing time 375
# Active requests at time 375: [18, 19, 21, 23, 24, 25, 26, 27, 28]
# Processing time 376
# Active requests at time 376: [18, 19, 21, 23, 24, 25, 26, 27, 28]
# Processing time 377
# Active requests at time 377: [18, 19, 21, 23, 24, 25, 26, 27, 28]
# Processing time 378
# Active requests at time 378: [18, 19, 21, 24, 25, 26, 27, 28]
# Processing time 379
# Active requests at time 379: [18, 19, 21, 24, 25, 26, 27, 28]
# Processing time 380
# Active requests at time 380: [18, 19, 21, 24, 25, 26, 27, 28]
# Processing time 381
# Active requests at time 381: [18, 19, 21, 24, 25, 26, 27, 28]
# Processing time 382
# Active requests at time 382: [18, 19, 21, 24, 25, 26, 27, 28]
# Processing time 383
# Active requests at time 383: [18, 19, 21, 24, 25, 26, 27, 28]
# Processing time 384
# Found path from 0 to 18 with required bandwidth 27: [0, 8, 24, 18]
# Active requests at time 384: [18, 19, 21, 24, 25, 26, 27, 28, 29]
# Processing time 385
# Active requests at time 385: [18, 19, 21, 24, 25, 26, 27, 28, 29]
# Processing time 386
# Active requests at time 386: [18, 19, 21, 24, 25, 26, 27, 28, 29]
# Processing time 387
# Active requests at time 387: [18, 19, 21, 24, 25, 26, 27, 28, 29]
# Processing time 388
# Active requests at time 388: [18, 19, 21, 24, 25, 26, 27, 28, 29]
# Processing time 389
# Active requests at time 389: [18, 19, 21, 24, 25, 26, 27, 28, 29]
# Processing time 390
# Active requests at time 390: [18, 19, 21, 24, 25, 26, 27, 28, 29]
# Processing time 391
# Active requests at time 391: [18, 19, 21, 24, 25, 26, 27, 28, 29]
# Processing time 392
# Active requests at time 392: [18, 19, 21, 24, 25, 26, 27, 28, 29]
# Processing time 393
# Active requests at time 393: [18, 19, 24, 25, 26, 27, 28, 29]
# Processing time 394
# Active requests at time 394: [18, 19, 24, 25, 26, 27, 28, 29]
# Processing time 395
# Active requests at time 395: [18, 19, 24, 25, 26, 27, 28, 29]
# Processing time 396
# Active requests at time 396: [18, 19, 24, 25, 26, 27, 28, 29]
# Processing time 397
# Active requests at time 397: [18, 19, 24, 25, 26, 27, 28, 29]
# Processing time 398
# Active requests at time 398: [18, 19, 24, 25, 26, 27, 28, 29]
# Processing time 399
# Active requests at time 399: [18, 19, 24, 25, 26, 27, 28, 29]
# Processing time 400
# Active requests at time 400: [18, 19, 24, 25, 26, 27, 28, 29]
# Processing time 401
# Active requests at time 401: [18, 19, 24, 25, 26, 27, 28, 29]
# Processing time 402
# Active requests at time 402: [18, 19, 24, 25, 26, 27, 28, 29]
# Processing time 403
# Active requests at time 403: [18, 19, 24, 25, 26, 27, 28, 29]
# Processing time 404
# Active requests at time 404: [18, 19, 24, 25, 26, 27, 28, 29]
# Processing time 405
# Active requests at time 405: [18, 19, 24, 25, 26, 27, 28, 29]
# Processing time 406
# Active requests at time 406: [18, 19, 24, 25, 26, 27, 28, 29]
# Processing time 407
# Active requests at time 407: [18, 19, 24, 25, 26, 27, 28, 29]
# Processing time 408
# Active requests at time 408: [18, 19, 24, 25, 26, 27, 28, 29]
# Processing time 409
# Active requests at time 409: [18, 19, 24, 25, 26, 27, 28, 29]
# Processing time 410
# Found path from 0 to 11 with required bandwidth 47: [0, 11]
# Active requests at time 410: [18, 19, 24, 25, 26, 27, 28, 29, 30]
# Processing time 411
# Active requests at time 411: [18, 19, 24, 25, 27, 28, 29, 30]
# Processing time 412
# Active requests at time 412: [18, 19, 24, 25, 27, 28, 29, 30]
# Processing time 413
# Active requests at time 413: [18, 19, 24, 25, 27, 28, 29, 30]
# Processing time 414
# Active requests at time 414: [18, 19, 24, 25, 27, 28, 29, 30]
# Processing time 415
# Active requests at time 415: [18, 19, 25, 27, 28, 29, 30]
# Processing time 416
# Active requests at time 416: [18, 19, 25, 27, 28, 29, 30]
# Processing time 417
# Active requests at time 417: [18, 19, 25, 27, 28, 29, 30]
# Processing time 418
# Active requests at time 418: [18, 19, 25, 27, 28, 29, 30]
# Processing time 419
# Active requests at time 419: [18, 19, 25, 27, 28, 29, 30]
# Processing time 420
# Active requests at time 420: [18, 19, 25, 27, 28, 29, 30]
# Processing time 421
# Found path from 6 to 14 with required bandwidth 89: [6, 14]
# Active requests at time 421: [18, 19, 25, 27, 28, 29, 30, 31]
# Processing time 422
# Active requests at time 422: [18, 19, 25, 27, 28, 29, 30, 31]
# Processing time 423
# Active requests at time 423: [18, 19, 25, 27, 28, 29, 30, 31]
# Processing time 424
# Active requests at time 424: [18, 19, 25, 27, 28, 29, 30, 31]
# Processing time 425
# Active requests at time 425: [18, 19, 25, 27, 28, 29, 30, 31]
# Processing time 426
# Found path from 5 to 17 with required bandwidth 50: [5, 14, 17]
# Active requests at time 426: [18, 19, 25, 27, 28, 29, 30, 31, 32]
# Processing time 427
# Active requests at time 427: [18, 19, 25, 27, 28, 29, 30, 31, 32]
# Processing time 428
# Active requests at time 428: [18, 19, 25, 27, 28, 29, 30, 31, 32]
# Processing time 429
# Active requests at time 429: [18, 19, 25, 27, 28, 29, 30, 31, 32]
# Processing time 430
# Active requests at time 430: [18, 19, 25, 27, 28, 29, 30, 31, 32]
# Processing time 431
# Active requests at time 431: [18, 19, 25, 27, 28, 29, 30, 31, 32]
# Processing time 432
# Active requests at time 432: [18, 19, 25, 27, 28, 29, 30, 31, 32]
# Processing time 433
# Active requests at time 433: [18, 19, 25, 27, 28, 29, 30, 31, 32]
# Processing time 434
# Active requests at time 434: [18, 19, 25, 27, 28, 29, 30, 31, 32]
# Processing time 435
# Active requests at time 435: [18, 19, 25, 27, 28, 29, 30, 31, 32]
# Processing time 436
# Active requests at time 436: [18, 19, 25, 27, 28, 29, 30, 31, 32]
# Processing time 437
# Active requests at time 437: [18, 19, 25, 27, 28, 29, 30, 31, 32]
# Processing time 438
# Active requests at time 438: [18, 19, 25, 27, 28, 29, 30, 31, 32]
# Processing time 439
# Active requests at time 439: [18, 19, 25, 27, 28, 29, 30, 31, 32]
# Processing time 440
# Active requests at time 440: [18, 19, 25, 27, 28, 29, 30, 31, 32]
# Processing time 441
# Active requests at time 441: [18, 19, 25, 27, 28, 29, 30, 31, 32]
# Processing time 442
# Active requests at time 442: [18, 19, 25, 27, 28, 29, 30, 31, 32]
# Processing time 443
# Active requests at time 443: [18, 19, 25, 27, 28, 29, 30, 31, 32]
# Processing time 444
# Found path from 7 to 14 with required bandwidth 99: [7, 17, 14]
# Active requests at time 444: [18, 19, 25, 27, 28, 29, 30, 31, 32, 33]
# Processing time 445
# Active requests at time 445: [18, 19, 25, 27, 28, 29, 30, 31, 32, 33]
# Processing time 446
# Active requests at time 446: [18, 25, 27, 28, 29, 30, 31, 32, 33]
# Processing time 447
# Active requests at time 447: [18, 25, 27, 28, 29, 30, 31, 32, 33]
# Processing time 448
# Active requests at time 448: [25, 27, 28, 29, 30, 31, 32, 33]
# Processing time 449
# Found path from 6 to 10 with required bandwidth 56: [6, 14, 17, 10]
# Active requests at time 449: [25, 27, 28, 29, 30, 31, 32, 33, 34]
# Processing time 450
# Active requests at time 450: [25, 27, 28, 29, 30, 31, 32, 33, 34]
# Processing time 451
# Active requests at time 451: [25, 27, 28, 29, 30, 31, 32, 33, 34]
# Processing time 452
# Active requests at time 452: [25, 27, 28, 29, 30, 31, 32, 33, 34]
# Processing time 453
# Active requests at time 453: [25, 27, 28, 29, 30, 31, 32, 33, 34]
# Processing time 454
# Active requests at time 454: [25, 27, 28, 29, 30, 31, 32, 33, 34]
# Processing time 455
# Active requests at time 455: [25, 27, 28, 29, 30, 31, 32, 33, 34]
# Processing time 456
# Active requests at time 456: [25, 27, 28, 29, 30, 31, 32, 33, 34]
# Processing time 457
# Active requests at time 457: [25, 27, 28, 29, 30, 31, 32, 33, 34]
# Processing time 458
# Active requests at time 458: [25, 27, 28, 29, 30, 31, 32, 33, 34]
# Processing time 459
# Active requests at time 459: [25, 27, 28, 29, 30, 31, 32, 33, 34]
# Processing time 460
# Active requests at time 460: [25, 27, 28, 29, 30, 31, 32, 34]
# Processing time 461
# Active requests at time 461: [25, 27, 28, 29, 30, 31, 32, 34]
# Processing time 462
# Active requests at time 462: [25, 27, 28, 29, 30, 31, 32, 34]
# Processing time 463
# Active requests at time 463: [25, 27, 28, 29, 30, 31, 32, 34]
# Processing time 464
# Active requests at time 464: [25, 27, 28, 29, 30, 31, 32, 34]
# Processing time 465
# Active requests at time 465: [25, 27, 28, 29, 30, 31, 32, 34]
# Processing time 466
# Active requests at time 466: [25, 27, 28, 29, 30, 31, 32, 34]
# Processing time 467
# Active requests at time 467: [25, 27, 28, 29, 30, 31, 32, 34]
# Processing time 468
# Active requests at time 468: [25, 27, 29, 30, 31, 32, 34]
# Processing time 469
# Active requests at time 469: [25, 27, 29, 30, 31, 32, 34]
# Processing time 470
# Active requests at time 470: [25, 27, 29, 30, 31, 32, 34]
# Processing time 471
# Active requests at time 471: [25, 27, 29, 30, 31, 32, 34]
# Processing time 472
# Active requests at time 472: [25, 27, 29, 30, 31, 32, 34]
# Processing time 473
# Active requests at time 473: [25, 27, 29, 30, 31, 32, 34]
# Processing time 474
# Active requests at time 474: [25, 27, 29, 30, 31, 32, 34]
# Processing time 475
# Active requests at time 475: [25, 27, 29, 30, 31, 32]
# Processing time 476
# Active requests at time 476: [25, 27, 29, 30, 31, 32]
# Processing time 477
# Active requests at time 477: [25, 27, 29, 30, 31, 32]
# Processing time 478
# Active requests at time 478: [25, 27, 29, 30, 31, 32]
# Processing time 479
# Found path from 5 to 14 with required bandwidth 41: [5, 14]
# Active requests at time 479: [25, 27, 29, 30, 31, 32, 35]
# Processing time 480
# Active requests at time 480: [25, 27, 29, 30, 31, 32, 35]
# Processing time 481
# Active requests at time 481: [25, 27, 29, 30, 31, 32, 35]
# Processing time 482
# Active requests at time 482: [25, 27, 29, 30, 31, 32, 35]
# Processing time 483
# Active requests at time 483: [25, 27, 29, 30, 31, 32, 35]
# Processing time 484
# Active requests at time 484: [25, 27, 29, 30, 31, 32, 35]
# Processing time 485
# Active requests at time 485: [25, 27, 29, 30, 31, 32, 35]
# Processing time 486
# Active requests at time 486: [25, 27, 29, 30, 31, 32, 35]
# Processing time 487
# Active requests at time 487: [25, 27, 29, 30, 31, 32, 35]
# Processing time 488
# Active requests at time 488: [25, 27, 29, 30, 31, 32, 35]
# Processing time 489
# Active requests at time 489: [25, 27, 29, 30, 31, 32, 35]
# Processing time 490
# Active requests at time 490: [25, 27, 29, 30, 31, 32, 35]
# Processing time 491
# Active requests at time 491: [25, 27, 29, 30, 31, 32, 35]
# Processing time 492
# Found path from 5 to 14 with required bandwidth 60: [5, 14]
# Active requests at time 492: [25, 27, 29, 30, 31, 32, 35, 36]
# Processing time 493
# Active requests at time 493: [25, 27, 29, 30, 31, 32, 35, 36]
# Processing time 494
# Active requests at time 494: [25, 27, 29, 30, 31, 32, 35, 36]
# Processing time 495
# Active requests at time 495: [25, 27, 29, 30, 31, 32, 35, 36]
# Processing time 496
# Active requests at time 496: [25, 27, 29, 30, 31, 32, 35, 36]
# Processing time 497
# Active requests at time 497: [25, 27, 29, 30, 31, 32, 35, 36]
# Processing time 498
# Active requests at time 498: [25, 27, 29, 30, 31, 32, 35, 36]
# Processing time 499
# Active requests at time 499: [25, 27, 29, 30, 31, 32, 35, 36]
# Processing time 500
# Active requests at time 500: [25, 27, 29, 30, 31, 32, 35, 36]
# Processing time 501
# Active requests at time 501: [25, 27, 29, 30, 31, 32, 35, 36]
# Processing time 502
# Found path from 2 to 18 with required bandwidth 18: [2, 6, 5, 24, 18]
# Active requests at time 502: [25, 27, 29, 30, 31, 32, 35, 36, 37]
# Processing time 503
# Active requests at time 503: [25, 27, 29, 30, 31, 32, 35, 36, 37]
# Processing time 504
# Active requests at time 504: [25, 27, 29, 30, 31, 32, 35, 36, 37]
# Processing time 505
# Active requests at time 505: [25, 27, 29, 30, 31, 32, 35, 36, 37]
# Processing time 506
# Active requests at time 506: [25, 27, 29, 30, 31, 32, 35, 36, 37]
# Processing time 507
# Active requests at time 507: [25, 27, 29, 30, 31, 32, 35, 36, 37]
# Processing time 508
# Active requests at time 508: [25, 27, 29, 30, 31, 32, 35, 36, 37]
# Processing time 509
# Active requests at time 509: [25, 27, 29, 30, 31, 32, 35, 36, 37]
# Processing time 510
# Active requests at time 510: [25, 27, 29, 30, 31, 32, 35, 36, 37]
# Processing time 511
# Active requests at time 511: [25, 27, 29, 30, 31, 32, 35, 36, 37]
# Processing time 512
# Active requests at time 512: [25, 27, 29, 30, 31, 32, 35, 36, 37]
# Processing time 513
# Active requests at time 513: [25, 27, 29, 30, 31, 32, 35, 36, 37]
# Processing time 514
# Found path from 1 to 16 with required bandwidth 34: [1, 24, 16]
# Active requests at time 514: [25, 27, 29, 30, 31, 32, 35, 36, 37, 38]
# Processing time 515
# Active requests at time 515: [25, 27, 29, 30, 31, 32, 35, 36, 37, 38]
# Processing time 516
# Active requests at time 516: [25, 27, 29, 30, 31, 32, 35, 36, 37, 38]
# Processing time 517
# Active requests at time 517: [25, 27, 29, 30, 31, 32, 35, 36, 37, 38]
# Processing time 518
# Active requests at time 518: [25, 27, 29, 30, 31, 32, 35, 36, 38]
# Processing time 519
# Active requests at time 519: [25, 27, 29, 30, 31, 32, 35, 36, 38]
# Processing time 520
# Active requests at time 520: [25, 27, 29, 30, 31, 32, 35, 36, 38]
# Processing time 521
# Active requests at time 521: [25, 27, 29, 30, 31, 32, 35, 36, 38]
# Processing time 522
# Active requests at time 522: [25, 27, 29, 30, 31, 32, 35, 36, 38]
# Processing time 523
# Active requests at time 523: [25, 27, 29, 30, 31, 32, 35, 36, 38]
# Processing time 524
# Active requests at time 524: [25, 27, 29, 30, 31, 32, 35, 36, 38]
# Processing time 525
# Active requests at time 525: [25, 27, 29, 30, 31, 32, 35, 36, 38]
# Processing time 526
# Active requests at time 526: [25, 27, 29, 30, 31, 32, 35, 36, 38]
# Processing time 527
# Active requests at time 527: [25, 27, 29, 30, 31, 32, 35, 36, 38]
# Processing time 528
# Active requests at time 528: [25, 27, 29, 30, 32, 35, 36, 38]
# Processing time 529
# Active requests at time 529: [25, 27, 29, 30, 32, 35, 36, 38]
# Processing time 530
# Active requests at time 530: [25, 27, 29, 30, 32, 35, 36, 38]
# Processing time 531
# Active requests at time 531: [25, 27, 29, 30, 32, 35, 36, 38]
# Processing time 532
# Active requests at time 532: [25, 27, 29, 30, 32, 35, 36, 38]
# Processing time 533
# Active requests at time 533: [25, 27, 29, 30, 32, 35, 36, 38]
# Processing time 534
# Active requests at time 534: [25, 27, 29, 30, 32, 35, 36, 38]
# Processing time 535
# Active requests at time 535: [25, 27, 29, 30, 32, 35, 36, 38]
# Processing time 536
# Active requests at time 536: [25, 27, 29, 30, 32, 35, 36, 38]
# Processing time 537
# Active requests at time 537: [25, 27, 29, 30, 32, 35, 36, 38]
# Processing time 538
# Found path from 4 to 15 with required bandwidth 44: [4, 27, 20, 15]
# Active requests at time 538: [25, 27, 29, 30, 32, 35, 36, 38, 39]
# Processing time 539
# Active requests at time 539: [25, 27, 29, 30, 32, 35, 36, 38, 39]
# Processing time 540
# Active requests at time 540: [25, 27, 29, 30, 32, 35, 36, 38, 39]
# Processing time 541
# Active requests at time 541: [25, 27, 29, 30, 32, 35, 36, 38, 39]
# Processing time 542
# Active requests at time 542: [25, 27, 29, 30, 32, 35, 36, 38, 39]
# Processing time 543
# Active requests at time 543: [25, 27, 29, 30, 32, 35, 36, 38, 39]
# Processing time 544
# Active requests at time 544: [25, 27, 29, 30, 32, 35, 36, 38, 39]
# Processing time 545
# Active requests at time 545: [25, 27, 29, 30, 32, 35, 36, 38, 39]
# Processing time 546
# Active requests at time 546: [25, 27, 29, 30, 32, 35, 36, 38, 39]
# Processing time 547
# Active requests at time 547: [25, 27, 29, 30, 32, 35, 36, 38, 39]
# Processing time 548
# Active requests at time 548: [25, 27, 29, 30, 32, 35, 36, 38, 39]
# Processing time 549
# Active requests at time 549: [25, 27, 29, 30, 32, 35, 36, 38, 39]
# Processing time 550
# Active requests at time 550: [25, 27, 29, 30, 32, 35, 36, 38, 39]
# Processing time 551
# Active requests at time 551: [25, 27, 29, 30, 32, 35, 36, 38, 39]
# Processing time 552
# Active requests at time 552: [25, 27, 29, 30, 32, 35, 36, 38, 39]
# Processing time 553
# Active requests at time 553: [25, 27, 29, 30, 32, 35, 36, 38, 39]
# Processing time 554
# Active requests at time 554: [25, 27, 30, 32, 35, 36, 38, 39]
# Processing time 555
# Active requests at time 555: [25, 27, 30, 32, 35, 36, 38, 39]
# Processing time 556
# Active requests at time 556: [25, 27, 30, 32, 35, 36, 38, 39]
# Processing time 557
# Active requests at time 557: [25, 27, 30, 32, 35, 36, 38, 39]
# Processing time 558
# Active requests at time 558: [25, 27, 30, 32, 35, 36, 38, 39]
# Processing time 559
# Active requests at time 559: [25, 27, 30, 32, 35, 36, 38, 39]
# Processing time 560
# Active requests at time 560: [25, 27, 30, 32, 35, 36, 38, 39]
# Processing time 561
# Active requests at time 561: [25, 27, 30, 32, 35, 36, 38, 39]
# Processing time 562
# Active requests at time 562: [25, 27, 30, 32, 35, 36, 38, 39]
# Processing time 563
# Active requests at time 563: [25, 27, 30, 32, 35, 36, 38, 39]
# Processing time 564
# Active requests at time 564: [25, 27, 30, 32, 35, 36, 38, 39]
# Processing time 565
# Active requests at time 565: [25, 27, 30, 32, 35, 36, 38, 39]
# Processing time 566
# Active requests at time 566: [25, 27, 30, 32, 35, 36, 38, 39]
# Processing time 567
# Active requests at time 567: [25, 27, 30, 32, 35, 36, 38, 39]
# Processing time 568
# Found path from 0 to 19 with required bandwidth 52: [0, 4, 1, 19]
# Active requests at time 568: [25, 27, 30, 32, 35, 36, 38, 39, 40]
# Processing time 569
# Active requests at time 569: [25, 27, 30, 32, 35, 36, 38, 39, 40]
# Processing time 570
# Active requests at time 570: [25, 27, 30, 32, 35, 36, 38, 39, 40]
# Processing time 571
# Active requests at time 571: [25, 27, 30, 32, 35, 36, 38, 39, 40]
# Processing time 572
# Active requests at time 572: [25, 27, 30, 32, 35, 38, 39, 40]
# Processing time 573
# Active requests at time 573: [25, 27, 30, 32, 35, 38, 39, 40]
# Processing time 574
# Active requests at time 574: [25, 27, 30, 32, 35, 38, 39, 40]
# Processing time 575
# Active requests at time 575: [25, 27, 30, 32, 35, 38, 39, 40]
# Processing time 576
# Active requests at time 576: [25, 27, 30, 32, 35, 38, 39, 40]
# Processing time 577
# Active requests at time 577: [25, 27, 30, 32, 35, 38, 39, 40]
# Processing time 578
# Active requests at time 578: [25, 27, 30, 32, 35, 38, 39, 40]
# Processing time 579
# Active requests at time 579: [25, 27, 30, 32, 35, 38, 39, 40]
# Processing time 580
# Active requests at time 580: [25, 27, 30, 32, 35, 38, 39, 40]
# Processing time 581
# Active requests at time 581: [25, 27, 30, 32, 35, 38, 39, 40]
# Processing time 582
# Active requests at time 582: [25, 27, 30, 32, 35, 38, 39, 40]
# Processing time 583
# Active requests at time 583: [25, 27, 30, 32, 35, 38, 39, 40]
# Processing time 584
# Active requests at time 584: [25, 27, 30, 32, 35, 38, 39, 40]
# Processing time 585
# Active requests at time 585: [25, 27, 30, 32, 35, 38, 39, 40]
# Processing time 586
# Found path from 3 to 15 with required bandwidth 2: [3, 7, 25, 15]
# Active requests at time 586: [25, 27, 30, 32, 35, 38, 39, 40, 41]
# Processing time 587
# Active requests at time 587: [25, 27, 30, 32, 35, 38, 39, 40, 41]
# Processing time 588
# Found path from 4 to 10 with required bandwidth 50: [4, 1, 21, 17, 10]
# Active requests at time 588: [25, 27, 30, 32, 35, 38, 39, 40, 41, 42]
# Processing time 589
# Active requests at time 589: [25, 27, 30, 32, 35, 38, 39, 40, 41, 42]
# Processing time 590
# Found path from 0 to 18 with required bandwidth 41: [0, 8, 24, 18]
# Active requests at time 590: [25, 27, 32, 35, 38, 39, 40, 41, 42, 43]
# Processing time 591
# Active requests at time 591: [25, 27, 32, 35, 38, 39, 40, 41, 42, 43]
# Processing time 592
# Active requests at time 592: [25, 27, 32, 35, 38, 39, 40, 41, 42, 43]
# Processing time 593
# Active requests at time 593: [25, 27, 32, 35, 38, 39, 40, 41, 42, 43]
# Processing time 594
# Active requests at time 594: [25, 27, 32, 35, 38, 39, 40, 41, 42, 43]
# Processing time 595
# Active requests at time 595: [25, 27, 32, 35, 38, 39, 40, 41, 42, 43]
# Processing time 596
# Active requests at time 596: [25, 27, 32, 35, 38, 39, 40, 41, 42, 43]
# Processing time 597
# Active requests at time 597: [25, 27, 32, 35, 38, 39, 40, 41, 42, 43]
# Processing time 598
# Active requests at time 598: [25, 27, 32, 35, 38, 39, 40, 41, 42, 43]
# Processing time 599
# Active requests at time 599: [25, 27, 32, 35, 38, 39, 40, 41, 42, 43]
# Processing time 600
# Active requests at time 600: [25, 27, 32, 35, 39, 40, 41, 42, 43]
# Processing time 601
# Active requests at time 601: [25, 27, 32, 35, 39, 40, 41, 42, 43]
# Processing time 602
# Active requests at time 602: [25, 27, 32, 35, 39, 40, 41, 42, 43]
# Processing time 603
# Active requests at time 603: [25, 27, 32, 35, 39, 40, 41, 42, 43]
# Processing time 604
# ...
# Active requests at time 23745: []
# Processing time 23746
# Active requests at time 23746: []
# Processing time 23747
# Active requests at time 23747: []
# Processing time 23748
# Active requests at time 23748: []
# Processing time 23749
# Active requests at time 23749: []
# Processing time 23750
# Active requests at time 23750: []
# Processing time 23751
# Active requests at time 23751: []
# Processing time 23752
# Active requests at time 23752: []
# Processing time 23753
# Active requests at time 23753: []
# Processing time 23754
# Active requests at time 23754: []
# Processing time 23755
# Active requests at time 23755: []
# Processing time 23756
# Active requests at time 23756: []
# Processing time 23757
# Active requests at time 23757: []
# Processing time 23758
# Active requests at time 23758: []
# Processing time 23759
# Active requests at time 23759: []
# Processing time 23760
# Active requests at time 23760: []
# Processing time 23761
# Active requests at time 23761: []
# Processing time 23762
# Active requests at time 23762: []
# Processing time 23763
# Active requests at time 23763: []
# Processing time 23764
# Active requests at time 23764: []
# Processing time 23765
# Active requests at time 23765: []
# Processing time 23766
# Active requests at time 23766: []
# Processing time 23767
# Active requests at time 23767: []
# Processing time 23768
# Active requests at time 23768: []
# Processing time 23769
# Active requests at time 23769: []
# Processing time 23770
# Active requests at time 23770: []
# Processing time 23771
# Active requests at time 23771: []
# Processing time 23772
# Active requests at time 23772: []
# Processing time 23773
# Active requests at time 23773: []
# Processing time 23774
# Active requests at time 23774: []
# Processing time 23775
# Active requests at time 23775: []
# Processing time 23776
# Active requests at time 23776: []
# Processing time 23777
# Active requests at time 23777: []
# Processing time 23778
# Active requests at time 23778: []
# Processing time 23779
# Active requests at time 23779: []
# Processing time 23780
# Active requests at time 23780: []
# Processing time 23781
# Active requests at time 23781: []
# Processing time 23782
# Active requests at time 23782: []
# Processing time 23783
# Active requests at time 23783: []
# Processing time 23784
# Active requests at time 23784: []
# Processing time 23785
# Active requests at time 23785: []
# Processing time 23786
# Active requests at time 23786: []
# Processing time 23787
# Active requests at time 23787: []
# Processing time 23788
# Active requests at time 23788: []
# Processing time 23789
# Active requests at time 23789: []
# Processing time 23790
# Active requests at time 23790: []
# Processing time 23791
# Active requests at time 23791: []
# Processing time 23792
# Active requests at time 23792: []
# Processing time 23793
# Active requests at time 23793: []
# Processing time 23794
# Active requests at time 23794: []
# Processing time 23795
# Active requests at time 23795: []
# Processing time 23796
# Active requests at time 23796: []
# Processing time 23797
# Active requests at time 23797: []
# Processing time 23798
# Active requests at time 23798: []
# Processing time 23799
# Active requests at time 23799: []
# Processing time 23800
# Active requests at time 23800: []
# Processing time 23801
# Active requests at time 23801: []
# Processing time 23802
# Active requests at time 23802: []
# Processing time 23803
# Active requests at time 23803: []
# Processing time 23804
# Active requests at time 23804: []
# Processing time 23805
# Active requests at time 23805: []
# Processing time 23806
# Active requests at time 23806: []
# Processing time 23807
# Active requests at time 23807: []
# Processing time 23808
# Active requests at time 23808: []
# Processing time 23809
# Active requests at time 23809: []
# Processing time 23810
# Active requests at time 23810: []
# Processing time 23811
# Active requests at time 23811: []
# Processing time 23812
# Active requests at time 23812: []
# Processing time 23813
# Active requests at time 23813: []
# Processing time 23814
# Active requests at time 23814: []
# Processing time 23815
# Active requests at time 23815: []
# Processing time 23816
# Active requests at time 23816: []
# Processing time 23817
# Active requests at time 23817: []
# Processing time 23818
# Active requests at time 23818: []
# Processing time 23819
# Active requests at time 23819: []
# Processing time 23820
# Active requests at time 23820: []
# Processing time 23821
# Active requests at time 23821: []
# Processing time 23822
# Active requests at time 23822: []
# Processing time 23823
# Active requests at time 23823: []
# Processing time 23824
# Active requests at time 23824: []
# Processing time 23825
# Active requests at time 23825: []
# Processing time 23826
# Active requests at time 23826: []
# Processing time 23827
# Active requests at time 23827: []
# Processing time 23828
# Active requests at time 23828: []
# Processing time 23829
# Active requests at time 23829: []
# Processing time 23830
# Active requests at time 23830: []
# Processing time 23831
# Active requests at time 23831: []
# Processing time 23832
# Active requests at time 23832: []
# Processing time 23833
# Active requests at time 23833: []
# Processing time 23834
# Active requests at time 23834: []
# Processing time 23835
# Active requests at time 23835: []
# Processing time 23836
# Active requests at time 23836: []
# Processing time 23837
# Active requests at time 23837: []
# Processing time 23838
# Active requests at time 23838: []
# Processing time 23839
# Active requests at time 23839: []
# Processing time 23840
# Active requests at time 23840: []
# Processing time 23841
# Active requests at time 23841: []
# Processing time 23842
# Active requests at time 23842: []
# Processing time 23843
# Active requests at time 23843: []
# Processing time 23844
# Active requests at time 23844: []
# Processing time 23845
# Active requests at time 23845: []
# Processing time 23846
# Active requests at time 23846: []
# Processing time 23847
# Active requests at time 23847: []
# Processing time 23848
# Active requests at time 23848: []
# Processing time 23849
# Active requests at time 23849: []
# Processing time 23850
# Active requests at time 23850: []
# Processing time 23851
# Active requests at time 23851: []
# Processing time 23852
# Active requests at time 23852: []
# Processing time 23853
# Active requests at time 23853: []
# Processing time 23854
# Active requests at time 23854: []
# Processing time 23855
# Active requests at time 23855: []
# Processing time 23856
# Active requests at time 23856: []
# Processing time 23857
# Active requests at time 23857: []
# Processing time 23858
# Active requests at time 23858: []
# Processing time 23859
# Active requests at time 23859: []
# Processing time 23860
# Active requests at time 23860: []
# Processing time 23861
# Active requests at time 23861: []
# Processing time 23862
# Active requests at time 23862: []
# Processing time 23863
# Active requests at time 23863: []
# Processing time 23864
# Active requests at time 23864: []
# Processing time 23865
# Active requests at time 23865: []
# Processing time 23866
# Active requests at time 23866: []
# Processing time 23867
# Active requests at time 23867: []
# Processing time 23868
# Active requests at time 23868: []
# Processing time 23869
# Active requests at time 23869: []
# Processing time 23870
# Active requests at time 23870: []
# Processing time 23871
# Active requests at time 23871: []
# Processing time 23872
# Active requests at time 23872: []
# Processing time 23873
# Active requests at time 23873: []
# Processing time 23874
# Active requests at time 23874: []
# Processing time 23875
# Active requests at time 23875: []
# Processing time 23876
# Active requests at time 23876: []
# Processing time 23877
# Active requests at time 23877: []
# Processing time 23878
# Active requests at time 23878: []
# Processing time 23879
# Active requests at time 23879: []
# Processing time 23880
# Active requests at time 23880: []
# Processing time 23881
# Active requests at time 23881: []
# Processing time 23882
# Active requests at time 23882: []
# Processing time 23883
# Active requests at time 23883: []
# Processing time 23884
# Active requests at time 23884: []
# Processing time 23885
# Active requests at time 23885: []
# Processing time 23886
# Active requests at time 23886: []
# Processing time 23887
# Active requests at time 23887: []
# Processing time 23888
# Active requests at time 23888: []
# Processing time 23889
# Active requests at time 23889: []
# Processing time 23890
# Active requests at time 23890: []
# Processing time 23891
# Active requests at time 23891: []
# Processing time 23892
# Active requests at time 23892: []
# Processing time 23893
# Active requests at time 23893: []
# Processing time 23894
# Active requests at time 23894: []
# Processing time 23895
# Active requests at time 23895: []
# Processing time 23896
# Active requests at time 23896: []
# Processing time 23897
# Active requests at time 23897: []
# Processing time 23898
# Active requests at time 23898: []
# Processing time 23899
# Active requests at time 23899: []
# Processing time 23900
# Active requests at time 23900: []
# Processing time 23901
# Active requests at time 23901: []
# Processing time 23902
# Active requests at time 23902: []
# Processing time 23903
# Active requests at time 23903: []
# Processing time 23904
# Active requests at time 23904: []
# Processing time 23905
# Active requests at time 23905: []
# Processing time 23906
# Active requests at time 23906: []
# Processing time 23907
# Active requests at time 23907: []
# Processing time 23908
# Active requests at time 23908: []
# Processing time 23909
# Active requests at time 23909: []
# Processing time 23910
# Active requests at time 23910: []
# Processing time 23911
# Active requests at time 23911: []
# Processing time 23912
# Active requests at time 23912: []
# Processing time 23913
# Active requests at time 23913: []
# Processing time 23914
# Active requests at time 23914: []
# Processing time 23915
# Active requests at time 23915: []
# Processing time 23916
# Active requests at time 23916: []
# Processing time 23917
# Active requests at time 23917: []
# Processing time 23918
# Active requests at time 23918: []
# Processing time 23919
# Active requests at time 23919: []
# Processing time 23920
# Active requests at time 23920: []
# Processing time 23921
# Active requests at time 23921: []
# Processing time 23922
# Active requests at time 23922: []
# Processing time 23923
# Active requests at time 23923: []
# Processing time 23924
# Active requests at time 23924: []
# Processing time 23925
# Active requests at time 23925: []
# Processing time 23926
# Active requests at time 23926: []
# Processing time 23927
# Active requests at time 23927: []
# Processing time 23928
# Active requests at time 23928: []
# Processing time 23929
# Active requests at time 23929: []
# Processing time 23930
# Active requests at time 23930: []
# Processing time 23931
# Active requests at time 23931: []
# Processing time 23932
# Active requests at time 23932: []
# Processing time 23933
# Active requests at time 23933: []
# Processing time 23934
# Active requests at time 23934: []
# Processing time 23935
# Active requests at time 23935: []
# Processing time 23936
# Active requests at time 23936: []
# Processing time 23937
# Active requests at time 23937: []
# Processing time 23938
# Active requests at time 23938: []
# Processing time 23939
# Active requests at time 23939: []
# Processing time 23940
# Active requests at time 23940: []
# Processing time 23941
# Active requests at time 23941: []
# Processing time 23942
# Active requests at time 23942: []
# Processing time 23943
# Active requests at time 23943: []
# Processing time 23944
# Active requests at time 23944: []
# Processing time 23945
# Active requests at time 23945: []
# Processing time 23946
# Active requests at time 23946: []
# Processing time 23947
# Active requests at time 23947: []
# Processing time 23948
# Active requests at time 23948: []
# Processing time 23949
# Active requests at time 23949: []
# Processing time 23950
# Active requests at time 23950: []
# Processing time 23951
# Active requests at time 23951: []
# Processing time 23952
# Active requests at time 23952: []
# Processing time 23953
# Active requests at time 23953: []
# Processing time 23954
# Active requests at time 23954: []
# Processing time 23955
# Active requests at time 23955: []
# Processing time 23956
# Active requests at time 23956: []
# Processing time 23957
# Active requests at time 23957: []
# Processing time 23958
# Active requests at time 23958: []
# Processing time 23959
# Active requests at time 23959: []
# Processing time 23960
# Active requests at time 23960: []
# Processing time 23961
# Active requests at time 23961: []
# Processing time 23962
# Active requests at time 23962: []
# Processing time 23963
# Active requests at time 23963: []
# Processing time 23964
# Active requests at time 23964: []
# Processing time 23965
# Active requests at time 23965: []
# Processing time 23966
# Active requests at time 23966: []
# Processing time 23967
# Active requests at time 23967: []
# Processing time 23968
# Active requests at time 23968: []
# Processing time 23969
# Active requests at time 23969: []
# Processing time 23970
# Active requests at time 23970: []
# Processing time 23971
# Active requests at time 23971: []
# Processing time 23972
# Active requests at time 23972: []
# Processing time 23973
# Active requests at time 23973: []
# Processing time 23974
# Active requests at time 23974: []
# Processing time 23975
# Active requests at time 23975: []
# Processing time 23976
# Active requests at time 23976: []
# Processing time 23977
# Active requests at time 23977: []
# Processing time 23978
# Active requests at time 23978: []
# Processing time 23979
# Active requests at time 23979: []
# Processing time 23980
# Active requests at time 23980: []
# Processing time 23981
# Active requests at time 23981: []
# Processing time 23982
# Active requests at time 23982: []
# Processing time 23983
# Active requests at time 23983: []
# Processing time 23984
# Active requests at time 23984: []
# Processing time 23985
# Active requests at time 23985: []
# Processing time 23986
# Active requests at time 23986: []
# Processing time 23987
# Active requests at time 23987: []
# Processing time 23988
# Active requests at time 23988: []
# Processing time 23989
# Active requests at time 23989: []
# Processing time 23990
# Active requests at time 23990: []
# Processing time 23991
# Active requests at time 23991: []
# Processing time 23992
# Active requests at time 23992: []
# Processing time 23993
# Active requests at time 23993: []
# Processing time 23994
# Active requests at time 23994: []
# Processing time 23995
# Active requests at time 23995: []
# Processing time 23996
# Active requests at time 23996: []
# Processing time 23997
# Active requests at time 23997: []
# Processing time 23998
# Active requests at time 23998: []
# Processing time 23999
# Active requests at time 23999: []
# Processing time 24000
# Active requests at time 24000: []
# Processing time 24001
# Active requests at time 24001: []
# Processing time 24002
# Active requests at time 24002: []
# Processing time 24003
# Active requests at time 24003: []
# Processing time 24004
# Active requests at time 24004: []
# Processing time 24005
# Active requests at time 24005: []
# Processing time 24006
# Active requests at time 24006: []
# Processing time 24007
# Active requests at time 24007: []
# Processing time 24008
# Active requests at time 24008: []
# Processing time 24009
# Active requests at time 24009: []
# Processing time 24010
# Active requests at time 24010: []
# Processing time 24011
# Active requests at time 24011: []
# Processing time 24012
# Active requests at time 24012: []
# Processing time 24013
# Active requests at time 24013: []
# Processing time 24014
# Active requests at time 24014: []
# Processing time 24015
# Active requests at time 24015: []
# Processing time 24016
# Active requests at time 24016: []
# Processing time 24017
# Active requests at time 24017: []
# Processing time 24018
# Active requests at time 24018: []
# Processing time 24019
# Active requests at time 24019: []
# Processing time 24020
# Active requests at time 24020: []
# Processing time 24021
# Active requests at time 24021: []
# Processing time 24022
# Active requests at time 24022: []
# Processing time 24023
# Active requests at time 24023: []
# Processing time 24024
# Active requests at time 24024: []
# Processing time 24025
# Active requests at time 24025: []
# Processing time 24026
# Active requests at time 24026: []
# Processing time 24027
# Active requests at time 24027: []
# Processing time 24028
# Active requests at time 24028: []
# Processing time 24029
# Active requests at time 24029: []
# Processing time 24030
# Active requests at time 24030: []
